# %%
import pandas as pd

# %% [markdown]
# ### Read in data

# %%
df = pd.read_csv('survey_results_public.csv.zip')

# %% [markdown]
# ### Do people only recognize the value of DevOps once they have it?

# %%
df.NEWDevOpsImpt.dropna().hist(xrot=60)
# Out:
# <AxesSubplot:>

# %% [markdown]
# -> People think it is important. Majority of developers think it is important

# %%
df.NEWDevOps.dropna().hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# But only has a dedicated DevOps person in their company

# %% [markdown]
# Of the people, that think it is important, how many do have a dedicated DevOps person?

# %%
devs_that_think_devops_is_important = df.loc[(df.NEWDevOpsImpt == "Somewhat important") | (df.NEWDevOpsImpt == "Extremely important")]

# %%
devs_that_think_devops_is_important.NEWDevOps.dropna().value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
devs_that_think_devops_is_important.NEWDevOps.dropna().hist()
# Out:
# <AxesSubplot:>

# %%
devs_that_think_devops_is_not_important = df.loc[(df.NEWDevOpsImpt == "Neutral") | (df.NEWDevOpsImpt == "Not at all important") | (df.NEWDevOpsImpt == "Not very important")]

# %%
devs_that_think_devops_is_important.NEWDevOps.dropna().hist()
# Out:
# <AxesSubplot:>
