# %%
import pandas as pd
import seaborn as sns
sns.set()
sns.set_style("dark")

# %% [markdown]
# ### Read in data

# %%
df = pd.read_csv('survey_results_public.csv.zip')

# %% [markdown]
# ### Do people only recognize the value of DevOps once they have it?

# %%
df.NEWDevOpsImpt.dropna().hist(xrot=60);

# %% [markdown]
# -> People think it is important. Majority of developers think it is important

# %%
df.NEWDevOps.dropna().hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# But only half has a dedicated DevOps person in their company

# %% [markdown]
# Of the people, that think it is important, how many do have a dedicated DevOps person?

# %%
devs_that_think_devops_is_important = df.loc[(df.NEWDevOpsImpt == "Somewhat important") | (df.NEWDevOpsImpt == "Extremely important")].dropna().NEWDevOps

# %%
(devs_that_think_devops_is_important.value_counts() / devs_that_think_devops_is_important.count() * 100).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
devs_that_think_devops_is_not_important = df.loc[(df.NEWDevOpsImpt == "Neutral") | (df.NEWDevOpsImpt == "Not at all important") | (df.NEWDevOpsImpt == "Not very important")].dropna().NEWDevOps

# %%
(devs_that_think_devops_is_not_important.value_counts() / devs_that_think_devops_is_not_important.count() * 100).plot(kind="bar");

# %% [markdown]
# Use seaborn pairgrid

# %% [markdown]
# # Does having DevOps increase developer satisfaction?

# %%
df.JobSat.hist(xrot=60)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # What is the state of DevOps with respect to company size - is it only applied in big companies?

# %%
df.OrgSize.hist(xrot=60)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Create line plot: Company size vs. Percentage of devs that has devops
